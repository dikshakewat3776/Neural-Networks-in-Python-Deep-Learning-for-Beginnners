# %% [markdown]
# # Gathering Business Knowledge

# %% [markdown]
# 1.  You must know the business context of the problem you are trying to solve.
# 2. Most important part of creating a model is to have a sound business knowledge and the typee of insights you are trying to derive.
# 3. The input data is derived from various kinds of research let it to primary or secondary.
# 4. The quality of inputs deciedes the quality of output.
# 5. For ex. Cart Abandonement Analysis

# %% [markdown]
# # Data Exploration:

# %% [markdown]
# Searching relevant data.

# %% [markdown]
# 1. Identify data needed.
# 2. Requesting data.
# 3. Quality checks of data.

# %% [markdown]
# Types of requested data:
#
# 1. Internal (data collected by organization)
# 2.   External (data acquired from external data sources)

# %% [markdown]
# Example:
# ![Example.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# Problem Statement : Consider you are a manager in a real estate company and you want to find the true value of the property and get the price of the property you want to sell.

# %% [markdown]
# # Dataset:

# %% [markdown]
# ![housingd1.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![housingd2.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# # Data Importing:

# %%
# %pwd
# Out:
# '/content'

# %%
# %ls
# Out:
# House_Price.csv  sample_data/

# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv('/content/House_Price.csv', header=0)

# %%
df.head()
# Out:
#    price  crime_rate  resid_area  ...  rainfall  bus_ter     parks
# 0   24.0     0.00632       32.31  ...        23      YES  0.049347
# 1   21.6     0.02731       37.07  ...        42      YES  0.046146
# 2   34.7     0.02729       37.07  ...        38      YES  0.045764
# 3   33.4     0.03237       32.18  ...        45      YES  0.047151
# 4   36.2     0.06905       32.18  ...        55      YES  0.039474
#
# [5 rows x 19 columns]

# %%
df.shape
# Out:
# (506, 19)

# %% [markdown]
# # Univariate Analysis:

# %% [markdown]
# Univariate analysis is the simplest form of analyzing data. “Uni” means “one”, so in other words your data has only one variable. It doesn’t deal with causes or relationships (unlike regression ) and it’s major purpose is to describe; It takes data, summarizes that data and finds patterns in the data.

# %% [markdown]
# ![univariate.jpg](data:image/jpeg;base64,...)

# %%
df.describe()
# Out:
#             price  crime_rate  resid_area  ...  n_hot_rooms    rainfall       parks
# count  506.000000  506.000000  506.000000  ...   506.000000  506.000000  506.000000
# mean    22.528854    3.613524   41.136779  ...    13.041605   39.181818    0.054454
# std      9.182176    8.601545    6.860353  ...     5.238957   12.513697    0.010632
# min      5.000000    0.006320   30.460000  ...    10.057600    3.000000    0.033292
# 25%     17.025000    0.082045   35.190000  ...    11.189800   28.000000    0.046464
# 50%     21.200000    0.256510   39.690000  ...    12.720000   39.000000    0.053507
# 75%     25.000000    3.677082   48.100000  ...    14.170800   50.000000    0.061397
# max     50.000000   88.976200   57.740000  ...   101.120000   60.000000    0.086711
#
# [8 rows x 16 columns]

# %%
sns.jointplot(x="n_hot_rooms", y="price" , data=df)  # Numerical variable

# %%
sns.jointplot(x="rainfall", y="price" , data=df)

# %%
sns.countplot(x="airport", data=df)  # categorical variable

# %%
sns.countplot(x="waterbody", data=df)

# %%
sns.countplot(x="bus_ter", data=df)

# %% [markdown]
# Conclusions from Extended Data Dictionary (EDD):
# 1. Missing values in n_hos_beds.
# 2. skewness or outliers in crime_rate.
# 3. outliers in n_hot_rooms
# 4. outliers in rainfall
# 5.  Bus_ter has only one value named 'YES'

# %% [markdown]
# # Outlier Treatment :

# %% [markdown]
# Outlier is an  observation that appears far away and diverges from the overall pattern in the sample.

# %% [markdown]
# ![outlier.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![outlier2.jpg](data:image/jpeg;base64,...)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 19 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   price        506 non-null    float64
#  1   crime_rate   506 non-null    float64
#  2   resid_area   506 non-null    float64
#  3   air_qual     506 non-null    float64
#  4   room_num     506 non-null    float64
#  5   age          506 non-null    float64
#  6   dist1        506 non-null    float64
#  7   dist2        506 non-null    float64
#  8   dist3        506 non-null    float64
#  9   dist4        506 non-null    float64
#  10  teachers     506 non-null    float64
#  11  poor_prop    506 non-null    float64
#  12  airport      506 non-null    object
#  13  n_hos_beds   498 non-null    float64
#  14  n_hot_rooms  506 non-null    float64
#  15  waterbody    506 non-null    object
#  16  rainfall     506 non-null    int64
#  17  bus_ter      506 non-null    object
# ...

# %%
#capping and flooring
np.percentile(df.n_hot_rooms,[99])
# Out:
# array([15.39952])

# %%
uv = np.percentile(df.n_hot_rooms,[99])[0]

# %%
df[(df.n_hot_rooms>uv)]
# Out:
#      price  crime_rate  resid_area  ...  rainfall  bus_ter     parks
# 2     34.7     0.02729       37.07  ...        38      YES  0.045764
# 166   50.0     2.01019       49.58  ...        37      YES  0.052105
# 204   50.0     0.02009       32.68  ...        51      YES  0.044178
# 267   50.0     0.57834       33.97  ...        42      YES  0.063235
# 369   50.0     5.66998       48.10  ...        58      YES  0.067477
# 423   13.4     7.05042       48.10  ...        29      YES  0.063344
#
# [6 rows x 19 columns]

# %%
df.n_hot_rooms[(df.n_hot_rooms>3*uv)] = 3*uv
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df[(df.n_hot_rooms>uv)]
# Out:
#      price  crime_rate  resid_area  ...  rainfall  bus_ter     parks
# 2     34.7     0.02729       37.07  ...        38      YES  0.045764
# 166   50.0     2.01019       49.58  ...        37      YES  0.052105
# 204   50.0     0.02009       32.68  ...        51      YES  0.044178
# 267   50.0     0.57834       33.97  ...        42      YES  0.063235
# 369   50.0     5.66998       48.10  ...        58      YES  0.067477
# 423   13.4     7.05042       48.10  ...        29      YES  0.063344
#
# [6 rows x 19 columns]

# %%
np.percentile(df.rainfall,[1])[0]
# Out:
# 20.0

# %%
lv  =  np.percentile(df.rainfall,[1])[0]

# %%
df[(df.rainfall<lv)]
# Out:
#      price  crime_rate  resid_area  ...  rainfall  bus_ter     parks
# 213   28.1     0.14052       40.59  ...         3      YES  0.044019
#
# [1 rows x 19 columns]

# %%
df.rainfall[(df.rainfall < 0.3*lv)] = 0.3*lv
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df[(df.rainfall<lv)]
# Out:
#      price  crime_rate  resid_area  ...  rainfall  bus_ter     parks
# 213   28.1     0.14052       40.59  ...         6      YES  0.044019
#
# [1 rows x 19 columns]

# %%
df.describe()
# Out:
#             price  crime_rate  resid_area  ...  n_hot_rooms    rainfall       parks
# count  506.000000  506.000000  506.000000  ...   506.000000  506.000000  506.000000
# mean    22.528854    3.613524   41.136779  ...    12.864050   39.187747    0.054454
# std      9.182176    8.601545    6.860353  ...     2.688778   12.497221    0.010632
# min      5.000000    0.006320   30.460000  ...    10.057600    6.000000    0.033292
# 25%     17.025000    0.082045   35.190000  ...    11.189800   28.000000    0.046464
# 50%     21.200000    0.256510   39.690000  ...    12.720000   39.000000    0.053507
# 75%     25.000000    3.677082   48.100000  ...    14.170800   50.000000    0.061397
# max     50.000000   88.976200   57.740000  ...    46.198560   60.000000    0.086711
#
# [8 rows x 16 columns]

# %% [markdown]
# # Missing Value Imputation:

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 19 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   price        506 non-null    float64
#  1   crime_rate   506 non-null    float64
#  2   resid_area   506 non-null    float64
#  3   air_qual     506 non-null    float64
#  4   room_num     506 non-null    float64
#  5   age          506 non-null    float64
#  6   dist1        506 non-null    float64
#  7   dist2        506 non-null    float64
#  8   dist3        506 non-null    float64
#  9   dist4        506 non-null    float64
#  10  teachers     506 non-null    float64
#  11  poor_prop    506 non-null    float64
#  12  airport      506 non-null    object
#  13  n_hos_beds   498 non-null    float64
#  14  n_hot_rooms  506 non-null    float64
#  15  waterbody    506 non-null    object
#  16  rainfall     506 non-null    int64
#  17  bus_ter      506 non-null    object
# ...

# %%
df.n_hos_beds = df.n_hos_beds.fillna(df.n_hos_beds.mean())

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 19 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   price        506 non-null    float64
#  1   crime_rate   506 non-null    float64
#  2   resid_area   506 non-null    float64
#  3   air_qual     506 non-null    float64
#  4   room_num     506 non-null    float64
#  5   age          506 non-null    float64
#  6   dist1        506 non-null    float64
#  7   dist2        506 non-null    float64
#  8   dist3        506 non-null    float64
#  9   dist4        506 non-null    float64
#  10  teachers     506 non-null    float64
#  11  poor_prop    506 non-null    float64
#  12  airport      506 non-null    object
#  13  n_hos_beds   506 non-null    float64
#  14  n_hot_rooms  506 non-null    float64
#  15  waterbody    506 non-null    object
#  16  rainfall     506 non-null    int64
#  17  bus_ter      506 non-null    object
# ...

# %% [markdown]
# # Seasonality:

# %% [markdown]
# Seasonality is presence of variations that occur at certain regular intervals like weekly, monthly , quaterly, yearly.

# %% [markdown]
# ![Seasonality.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# # Bivariate Analysis:

# %% [markdown]
# Bivariate analysis is the simultaneous analysis of two variables (attributes). It explores the concept of relationship between two variables, whether there exists an association and the strength of this association, or whether there are differences between two variables and the significance of these differences.
#
# There are three types of bivariate analysis.
#
#       Numerical & Numerical
#       Categorical & Categorical
#       Numerical & Categorical

# %% [markdown]
# ![bivariate1.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# # Variable Transformation:

# %% [markdown]
# ![variabletrans.jpg](data:image/jpeg;base64,...)

# %%
sns.jointplot(x="crime_rate", y="price", data=df)

# %% [markdown]
# logarithmic curve

# %%
df.crime_rate = np.log(1+df.crime_rate)

# %%
sns.jointplot(x="crime_rate", y="price", data=df)

# %% [markdown]
# linear relationship  obtained.

# %% [markdown]
# dist1, dist2, dist3, dist4 are conveying the same information

# %%
df['avg_dist'] = (df.dist1+df.dist2+df.dist3+df.dist4)/4

# %%
df.head()
# Out:
#    price  crime_rate  resid_area  ...  bus_ter     parks  avg_dist
# 0   24.0    0.006300       32.31  ...      YES  0.049347    4.0875
# 1   21.6    0.026944       37.07  ...      YES  0.046146    4.9675
# 2   34.7    0.026924       37.07  ...      YES  0.045764    4.9675
# 3   33.4    0.031857       32.18  ...      YES  0.047151    6.0650
# 4   36.2    0.066770       32.18  ...      YES  0.039474    6.0625
#
# [5 rows x 20 columns]

# %%
df.describe()
# Out:
#             price  crime_rate  resid_area  ...    rainfall       parks    avg_dist
# count  506.000000  506.000000  506.000000  ...  506.000000  506.000000  506.000000
# mean    22.528854    0.813418   41.136779  ...   39.187747    0.054454    3.795104
# std      9.182176    1.022731    6.860353  ...   12.497221    0.010632    2.105859
# min      5.000000    0.006300   30.460000  ...    6.000000    0.033292    1.127500
# 25%     17.025000    0.078853   35.190000  ...   28.000000    0.046464    2.100625
# 50%     21.200000    0.228336   39.690000  ...   39.000000    0.053507    3.207500
# 75%     25.000000    1.542674   48.100000  ...   50.000000    0.061397    5.187500
# max     50.000000    4.499545   57.740000  ...   60.000000    0.086711   12.127500
#
# [8 rows x 17 columns]

# %%
del df['dist1']
del df['dist2']
del df['dist3']
del df['dist4']

# %%
df.describe()
# Out:
#             price  crime_rate  resid_area  ...    rainfall       parks    avg_dist
# count  506.000000  506.000000  506.000000  ...  506.000000  506.000000  506.000000
# mean    22.528854    0.813418   41.136779  ...   39.187747    0.054454    3.795104
# std      9.182176    1.022731    6.860353  ...   12.497221    0.010632    2.105859
# min      5.000000    0.006300   30.460000  ...    6.000000    0.033292    1.127500
# 25%     17.025000    0.078853   35.190000  ...   28.000000    0.046464    2.100625
# 50%     21.200000    0.228336   39.690000  ...   39.000000    0.053507    3.207500
# 75%     25.000000    1.542674   48.100000  ...   50.000000    0.061397    5.187500
# max     50.000000    4.499545   57.740000  ...   60.000000    0.086711   12.127500
#
# [8 rows x 13 columns]

# %%
del  df['bus_ter']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   price        506 non-null    float64
#  1   crime_rate   506 non-null    float64
#  2   resid_area   506 non-null    float64
#  3   air_qual     506 non-null    float64
#  4   room_num     506 non-null    float64
#  5   age          506 non-null    float64
#  6   teachers     506 non-null    float64
#  7   poor_prop    506 non-null    float64
#  8   airport      506 non-null    object
#  9   n_hos_beds   506 non-null    float64
#  10  n_hot_rooms  506 non-null    float64
#  11  waterbody    506 non-null    object
#  12  rainfall     506 non-null    int64
#  13  parks        506 non-null    float64
#  14  avg_dist     506 non-null    float64
# dtypes: float64(12), int64(1), object(2)
# memory usage: 59.4+ KB

# %%
df.head()
# Out:
#    price  crime_rate  resid_area  ...  rainfall     parks  avg_dist
# 0   24.0    0.006300       32.31  ...        23  0.049347    4.0875
# 1   21.6    0.026944       37.07  ...        42  0.046146    4.9675
# 2   34.7    0.026924       37.07  ...        38  0.045764    4.9675
# 3   33.4    0.031857       32.18  ...        45  0.047151    6.0650
# 4   36.2    0.066770       32.18  ...        55  0.039474    6.0625
#
# [5 rows x 15 columns]

# %% [markdown]
# # Non-Usable Variables:

# %% [markdown]
# Identify non-usable variables to decrease the dimensionality of your dataset.
#
# Non-usable variables are like:
#
#     1. Variables with single unique value.
#
#     2. Variables with low fill rate.
#
#     3. Variables with regulatory issue.
#
#     4. Variable with no business sense.

# %% [markdown]
# # Dummy Variable:

# %% [markdown]
# A dummy variable (aka, an indicator variable) is a numeric variable that represents data with two or more distinct categories.

# %% [markdown]
# ![Dummy.jpg](data:image/jpeg;base64,...)

# %%
df = pd.get_dummies(df)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 19 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   price                     506 non-null    float64
#  1   crime_rate                506 non-null    float64
#  2   resid_area                506 non-null    float64
#  3   air_qual                  506 non-null    float64
#  4   room_num                  506 non-null    float64
#  5   age                       506 non-null    float64
#  6   teachers                  506 non-null    float64
#  7   poor_prop                 506 non-null    float64
#  8   n_hos_beds                506 non-null    float64
#  9   n_hot_rooms               506 non-null    float64
#  10  rainfall                  506 non-null    int64
#  11  parks                     506 non-null    float64
#  12  avg_dist                  506 non-null    float64
# ...

# %%
df.head()
# Out:
#    price  crime_rate  ...  waterbody_None  waterbody_River
# 0   24.0    0.006300  ...               0                1
# 1   21.6    0.026944  ...               0                0
# 2   34.7    0.026924  ...               1                0
# 3   33.4    0.031857  ...               0                0
# 4   36.2    0.066770  ...               0                0
#
# [5 rows x 19 columns]

# %% [markdown]
# Removing redundant columns or columns that derive same conclusions as any other column

# %%
del df['airport_NO']
del df['waterbody_None']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 17 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   price                     506 non-null    float64
#  1   crime_rate                506 non-null    float64
#  2   resid_area                506 non-null    float64
#  3   air_qual                  506 non-null    float64
#  4   room_num                  506 non-null    float64
#  5   age                       506 non-null    float64
#  6   teachers                  506 non-null    float64
#  7   poor_prop                 506 non-null    float64
#  8   n_hos_beds                506 non-null    float64
#  9   n_hot_rooms               506 non-null    float64
#  10  rainfall                  506 non-null    int64
#  11  parks                     506 non-null    float64
#  12  avg_dist                  506 non-null    float64
# ...

# %% [markdown]
# # Correlation:

# %% [markdown]
# 1. Correlation is any statistical relationship, whether causal or not, between two random variables or bivariate data. In the broadest sense correlation is any statistical association, though it commonly refers to the degree to which a pair of variables are linearly related.
#
# 2. Variables within a dataset can be related for lots of reasons.
#
# 3. For example:
#
#         a. One variable could cause or depend on the values of another variable.
#         b. One variable could be lightly associated with another variable.
#         c. Two variables could depend on a third unknown variable.
#
# 4. It can be useful in data analysis and modeling to better understand the relationships between variables. The statistical relationship between two variables is referred to as their correlation.
#
# 5. A correlation could be positive, meaning both variables move in the same direction, or negative, meaning that when one variable’s value increases, the other variables’ values decrease. Correlation can also be neutral or zero, meaning that the variables are unrelated.
#
#         a. Positive Correlation: both variables change in the same direction.
#         b. Neutral Correlation: No relationship in the change of the variables.
#         c. Negative Correlation: variables change in opposite directions.

# %% [markdown]
# Correaltion is not same as causation:

# %% [markdown]
# ![correlation-vs-causation-lg.gif](data:image/gif;base64,...)

# %% [markdown]
# Applications of correlation:
#
#     a. Summarize large amounts of data to discover patterns.
#
#     b. To identify colinearity in data.

# %%
df.corr()
# Out:
#                              price  ...  waterbody_River
# price                     1.000000  ...         0.071751
# crime_rate               -0.466527  ...        -0.060099
# resid_area               -0.484754  ...        -0.098976
# air_qual                 -0.429300  ...        -0.037772
# room_num                  0.696304  ...         0.046251
# age                      -0.377999  ...        -0.088609
# teachers                  0.505655  ...         0.094256
# poor_prop                -0.740836  ...        -0.109004
# n_hos_beds                0.108880  ...        -0.074148
# n_hot_rooms               0.017007  ...        -0.064096
# rainfall                 -0.047200  ...        -0.037016
# parks                    -0.391574  ...        -0.048862
# avg_dist                  0.249289  ...         0.032247
# airport_YES               0.182867  ...         0.017341
# waterbody_Lake            0.036233  ...        -0.366563
# ...
