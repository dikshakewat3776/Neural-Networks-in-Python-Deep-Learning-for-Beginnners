# %% [markdown]
# # NEURAL NETWORK STACKING

# %% [markdown]
# # 1. Parallel Stacking

# %% [markdown]
# ![parallelstacking.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# With parallel Stacking ,  we can get multiple outputs for the same inputs.

# %% [markdown]
# # 2. Sequential Stacking

# %% [markdown]
# ![sequentialstacking.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# In Sequential Stacking, output of one set of parallelly stacked neurons is sequentially fed as input to next set of parallelly stacked neurons.

# %% [markdown]
# # Nomenclature:

# %% [markdown]
# ![Nomenclature0.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![nomenclature.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# # TRAINING PROCESS:

# %% [markdown]
# ![training.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# 1.   To train our neural network (once the architecture is chosen) the first thing we must do is to initialize its parameters.
#
# 2. Initialize the weights randomly in order to help our network, breaking its symmetry. The goal is to prevent all neurons in a layer from learning the same thing.
#
# 3. Initialize the biases to zero.
#
# 4. From here we’ll proceed iteratively by following an optimization algorithm that will try to minimize the difference between the actual output and the one estimated by the network.
#
# 5. One  such optimization technique is Gradient Descent.

# %% [markdown]
# # GRADIENT DESCENT:

# %% [markdown]
# 1.   The most used algorithm to train neural networks is gradient descent.
#
# 2.   The gradient is a numeric calculation allowing us to know how to adjust the parameters of a network in such a way that its output deviation is minimized.

# %% [markdown]
# ![gradientdescent.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# # Gradient Descent Algorithm:
#
# ---

# %% [markdown]
# 1.  We introduce a mini-batch input with N random samples from our previously labeled training dataset (we have the actual output).
#
# 2. After the appropriate calculations on each layer of the network, we obtain the predictions at the output. This step is known as forward propagation (of the input).
#
# 3. We evaluate the loss function for the mini-batch. We evaluate the difference between the predictions of our network and the actual labels, in a proper way. The value of this loss function is the number the algorithm is trying to minimize. For ex. loss function for regression problem is Mean Squared Error(MSE), for classification it can be Binary Cross Entropy or Cross Entropy depending upon the output type.
#
# 4. We calculate the gradient as the multi-variable derivative of the loss function with respect to all the network parameters. Graphically it would be the slope of the tangent line to the loss function at the current point (evaluating the current parameter values).
#
# 5. We have an algorithm known as back-propagation (or backward propagation). This algorithm starts by calculating the partial derivatives of the loss function with respect to the parameters of the last layer, which don’t influence over any other network parameters.
#
# 6. Once the gradient vector is obtained, we’ll update the network parameters by subtracting the corresponding gradient value from their current values, multiplied by a learning rate that allows us to adjust the magnitude of our steps. The update term is subtracted because as we’ve seen before we want to move in the opposite direction to the gradient, decreasing the loss value.

# %% [markdown]
# ![Errorfunction.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# # Error Function:

# %% [markdown]
# 1. Error functions differ pased on the type of learning being performed.
#
# 2. For classification problems we use Cross Entropy Error Function.
#
# 3. Advantage of cross entopy loss function is that we do not have local minima's.
#
# 4. Gradient descent won't work properly given a local minima as it might stop there instead of finding the global minima.

# %% [markdown]
# ![crossentropy.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![crossentropyexample.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# # Back Propagation

# %% [markdown]
# 1. Back-propagation is the essence of neural net training. It is the method of fine-tuning the weights of a neural net based on the error rate obtained in the previous epoch (i.e., iteration).
#
# 2. Proper tuning of the weights allows you to reduce error rates and to make the model reliable by increasing its generalization.
#
# 3. Backpropagation is a short form for "backward propagation of errors." This method helps to calculate the gradient of a loss function with respects to all the weights in the network.

# %% [markdown]
# ![backpropagationjpg.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# 1. Inputs X, arrive through the preconnected path
#
# 2. Input is modeled using real weights W. The weights are usually randomly selected.
#
# 3. Calculate the output for every neuron from the input layer, to the hidden layers, to the output layer.
#
# 4. Calculate the error in the outputs
#
#          Error= Actual Output – Desired Output
#
# 5. Travel back from the output layer to the hidden layer to adjust the weights such that the error is decreased.
#
# 6. Keep repeating the process until the desired output is achieved

# %% [markdown]
# # Hyperparmaters:

# %% [markdown]
# 1. Hyperparameters are the variables which determines the network structure(Eg: Number of Hidden Units) and the variables which determine how the network is trained(Eg: Learning Rate).
#
# 2.  Hyperparameters are set before training(before optimizing the weights and bias).

# %% [markdown]
# **Classification Hyperparameters:**

# %% [markdown]
# ![classificationhyperparameters.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# **Regression Hyperparameters:**

# %% [markdown]
# ![regressionhyperparameters.jpg](data:image/jpeg;base64,...)
